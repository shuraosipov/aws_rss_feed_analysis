# %%
import pandas as pd

# %%
df = pd.read_csv('aws_release_notes.csv')

# %%
df
# Out:
#                                                     id  \
# 0             423114fd12589d1cd9fc065f562c538fb650a1d4
# 1             bd463ba84eb001015880cc085a89672f4613d7c6
# 2             81241520a8cbce799c4719645099ed9a871686b6
# 3             1bea1acaf2768efa19d220d0a6c956b09521c9ff
# 4             baaf5c3e1527e86360181a2bb05720c28772633d
# ..                                                 ...
# 621   <li><b>Game State Cloud Saving:</b> Maintain ...
# 622   <li><b>User Gameplay Data:</b> Maintain game-...
# 623                                              </ul>
# 624           fbfe7dcee1f03216635a9c0cd0ba3644677244c9
# 625           e78141aad8305f306915297387b806676d256738
#
#                                           services  \
# 0     amazon-ebs-snapshots-archive aws-govcloud-us
# 1                     amazon-ebs-snapshots-archive
# 2                           aws-fargate amazon-ecs
# 3       aws-step-functions application-integration
# 4
# ...

# %%
# drop rows with NaN values
df = df.dropna()

# %%
df
# Out:
#                                            id  \
# 0    423114fd12589d1cd9fc065f562c538fb650a1d4
# 1    bd463ba84eb001015880cc085a89672f4613d7c6
# 2    81241520a8cbce799c4719645099ed9a871686b6
# 3    1bea1acaf2768efa19d220d0a6c956b09521c9ff
# 4    baaf5c3e1527e86360181a2bb05720c28772633d
# ..                                        ...
# 615  b20c07c8d252cd1ed275a5eb6fc99f583f92de34
# 616  bb11cf32ded82d9671371246f9f5d6a758f8001d
# 617  0a9a378ef287b4b6720ceb2d4387dd1bbdd4a91f
# 624  fbfe7dcee1f03216635a9c0cd0ba3644677244c9
# 625  e78141aad8305f306915297387b806676d256738
#
#                                           services  \
# 0     amazon-ebs-snapshots-archive aws-govcloud-us
# 1                     amazon-ebs-snapshots-archive
# 2                           aws-fargate amazon-ecs
# 3       aws-step-functions application-integration
# 4
# ..                                             ...
# 615                                        aws-iot
# ...

# %%
df['services']
# Out:
# 0       amazon-ebs-snapshots-archive aws-govcloud-us
# 1                       amazon-ebs-snapshots-archive
# 2                             aws-fargate amazon-ecs
# 3         aws-step-functions application-integration
# 4
#                            ...
# 615                                          aws-iot
# 616                                  amazon-workmail
# 617                                aws-migration-hub
# 624                   aws-database-migration-service
# 625                   aws-database-migration-service
# Name: services, Length: 575, dtype: object

# %%
# remove spaces from the beginning and end of the string in the 'services' column
df['services'] = df['services'].str.strip()
# Out:
# /var/folders/kx/srnzh5s55_58vgpy40167mqw0000gn/T/ipykernel_31216/2197813535.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['services'] = df['services'].str.strip()

# %%
# split cell into multiple rows based on the space separator
df3 = df.assign(services=df.services.str.split(' ')).explode('services')

# %%
df3
# Out:
#                                            id                        services  \
# 0    423114fd12589d1cd9fc065f562c538fb650a1d4    amazon-ebs-snapshots-archive
# 0    423114fd12589d1cd9fc065f562c538fb650a1d4                 aws-govcloud-us
# 1    bd463ba84eb001015880cc085a89672f4613d7c6    amazon-ebs-snapshots-archive
# 2    81241520a8cbce799c4719645099ed9a871686b6                     aws-fargate
# 2    81241520a8cbce799c4719645099ed9a871686b6                      amazon-ecs
# ..                                        ...                             ...
# 615  b20c07c8d252cd1ed275a5eb6fc99f583f92de34                         aws-iot
# 616  bb11cf32ded82d9671371246f9f5d6a758f8001d                 amazon-workmail
# 617  0a9a378ef287b4b6720ceb2d4387dd1bbdd4a91f               aws-migration-hub
# 624  fbfe7dcee1f03216635a9c0cd0ba3644677244c9  aws-database-migration-service
# 625  e78141aad8305f306915297387b806676d256738  aws-database-migration-service
#
# ...

# %%
# save dateframe to csv
df3.to_csv('aws_release_notes_cleaned.csv', index=False, sep=';')
